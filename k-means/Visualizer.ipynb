# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("mall_customers.csv")

sns.scatterplot(
    x=df["Annual Income (k$)"], 
    y=df["Spending Score (1-100)"]
)

# %%
df2 = pd.read_csv("points_iter_9.csv")

sns.scatterplot(
    x=df2["x"], 
    y=df2["y"],
    hue=df2["clusterIdx"],
    palette=sns.color_palette(n_colors=6)
)

# %%
df2 = pd.read_csv("centroids_iter_9.csv")

sns.scatterplot(
    x=df2["x"], 
    y=df2["y"],
    hue=df2["clusterIdx"],
    palette=sns.color_palette(n_colors=6)
)
